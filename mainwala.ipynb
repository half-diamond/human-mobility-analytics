# %%
import addressf as ad
import os

# %%
map = ad.Map(r"C:\Users\Deepanshu Sharma\Downloads\map (2)")
# Out:
# Loadeding map ...
# Extracting relations ...
# Progress : 100%|██████████| 6845/6845 [03:49<00:00, 29.86it/s]
# Extracting ways ...

# %%
res = []
for i in os.scandir("trail"):
    if i.name in os.listdir("out"):
        print(f"File name {i.name} already done ...")
    else:
        map.process_file(i.path,i.name)
# Out:
# File name 004.csv already done ...
# File name 014.csv already done ...
# <●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●> 13738/13738 [100%] in 5.9s (2366.67/s
# <●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●> 6678/6678 [100%] in 3.8s (1730.66/s)
# <●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●> 36576/36576 [100%] in 18.1s (2027.60/
# <●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●●> 38572/38572 [100%] in 19.9s (1938.43/

# %%
map.find_location(39.99041,116.3052)
# Out:
# {'is_outside': 0,
#  'area4': '燕园街道',
#  'name': 'Peking University',
#  'type': 'university'}
